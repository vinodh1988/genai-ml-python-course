# %%
listx=[1,3,5,6,56,4,34,5,34,67,89,90,12,23,45,67,78,89,91,100]
listy=[]
for i in listx:
    listy.append(i*i)
print(listy)
# Out:
# [1, 9, 25, 36, 3136, 16, 1156, 25, 1156, 4489, 7921, 8100, 144, 529, 2025, 4489, 6084, 7921, 8281, 10000]

# %%
listx=(14,534,34,53,23,12,65,78,91,26,39,48,50,61,73,88,99,100)
listy=[x**2 for x in listx]
print(listy)
# Out:
# [196, 285156, 1156, 2809, 529, 144, 4225, 6084, 8281, 676, 1521, 2304, 2500, 3721, 5329, 7744, 9801, 10000]

# %%
listy=[1234,5678,91011,1213,1415,161718,1920,2122,2324,2526,2728,2930]
filtered_list = []
for value in listy:
    if value > 5000:
        filtered_list.append(value)
print(filtered_list)
# Out:
# [5678, 91011, 161718]

# %%
filtered_list_comprehension = [v for v in listy if v > 5000]
print(filtered_list_comprehension)
# Out:
# [5678, 91011, 161718]

# %%
for x in range(1,11):
    print(f"Square of {x} is {x**2}")
# Out:
# Square of 1 is 1
# Square of 2 is 4
# Square of 3 is 9
# Square of 4 is 16
# Square of 5 is 25
# Square of 6 is 36
# Square of 7 is 49
# Square of 8 is 64
# Square of 9 is 81
# Square of 10 is 100

# %%
listx=(14,534,34,53,23,12,65,78,91,26,39,48,50,61,73,88,99,100)
available = True if 50 in listx else False
print(available)

name="Roshan"
hasR=True if 'R' in name else False
print(hasR)
# Out:
# True
# True
